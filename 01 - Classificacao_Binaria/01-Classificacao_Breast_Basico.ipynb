# %%
# Udando tensorflow==2.0.0

# Bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

from tensorflow.keras.layers import Dense
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
# Carregando dados;
data = pd.read_csv('../Databases/entradas_breast.csv') # Features;
labels = pd.read_csv('../Databases/saidas_breast.csv') # Classes;

# Dividindo dados de treino e de teste;
X_train, X_test, y_train, y_test = train_test_split(data,       
                                                    labels,
                                                    test_size=0.25) # 25% dos dados serão para teste;

# %%
# Construindo rede neural;
# calculo de quantidade de neurronios para camada oculta: (Entradas + Saidas)/2, Exemplo: (30 + 1)/2 = 15.5, arredondando => 16 Neuronio na camada oculta;
model = Sequential([
               Dense(units=16, activation = 'relu', kernel_initializer = 'random_uniform', input_dim=30),
               Dense(units=16, activation = 'relu', kernel_initializer = 'random_uniform'),
               Dense(units=1, activation = 'sigmoid')])

# %%
# Configurando a rede neural;
optimizer = keras.optimizers.Adam(lr = 0.001,     # Learning Rate;
                                 decay = 0.0001,  # Muda o lr ao longo do tempo;
                                 clipvalue = 0.5) # Limites do gradiente de aprendizado;
 
model.compile(optimizer=optimizer,
              loss="binary_crossentropy",  # Erro do modelo para classificação binaria;
              metrics=["binary_accuracy"]) # Metrica de avaliação;

model.fit(X_train, y_train,  batch_size = 10, epochs = 100)
# Out:
# Train on 426 samples
# Epoch 1/100
# 426/426 [==============================] - 0s 1ms/sample - loss: 0.7676 - binary_accuracy: 0.6127
# Epoch 2/100
# 426/426 [==============================] - 0s 105us/sample - loss: 0.4882 - binary_accuracy: 0.7183
# Epoch 3/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.4444 - binary_accuracy: 0.7793
# Epoch 4/100
# 426/426 [==============================] - 0s 103us/sample - loss: 0.4234 - binary_accuracy: 0.7793
# Epoch 5/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.3515 - binary_accuracy: 0.8638
# Epoch 6/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.3303 - binary_accuracy: 0.8474
# Epoch 7/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.3241 - binary_accuracy: 0.8592
# Epoch 8/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.3345 - binary_accuracy: 0.8592
# Epoch 9/100
# 426/426 [==============================] - 0s 103us/sample - loss: 0.2677 - binary_accuracy: 0.8920
# Epoch 10/100
# 426/426 [==============================] - 0s 106us/sample - loss: 0.3092 - binary_accuracy: 0.8685
# Epoch 11/100
# 426/426 [==============================] - 0s 112us/sample - loss: 0.2647 - binary_accuracy: 0.8920
# Epoch 12/100
# 426/426 [==============================] - 0s 109us/sample - loss: 0.2430 - binary_accuracy: 0.8991
# Epoch 13/100
# 426/426 [==============================] - 0s 117us/sample - loss: 0.2807 - binary_accuracy: 0.8873
# Epoch 14/100
# 426/426 [==============================] - 0s 105us/sample - loss: 0.2647 - binary_accuracy: 0.8873
# Epoch 15/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.2545 - binary_accuracy: 0.8944
# Epoch 16/100
# 426/426 [==============================] - 0s 110us/sample - loss: 0.2230 - binary_accuracy: 0.9178
# Epoch 17/100
# 426/426 [==============================] - 0s 108us/sample - loss: 0.2172 - binary_accuracy: 0.9108
# 426/426 [==============================] - 0s 105us/sample - loss: 0.1294 - binary_accuracy: 0.9554
# Epoch 76/100
# 426/426 [==============================] - 0s 119us/sample - loss: 0.1126 - binary_accuracy: 0.9531
# Epoch 77/100
# 426/426 [==============================] - 0s 229us/sample - loss: 0.1220 - binary_accuracy: 0.9577
# Epoch 78/100
# 426/426 [==============================] - 0s 178us/sample - loss: 0.1397 - binary_accuracy: 0.9366
# Epoch 79/100
# 426/426 [==============================] - 0s 157us/sample - loss: 0.1653 - binary_accuracy: 0.9343
# Epoch 80/100
# 426/426 [==============================] - 0s 185us/sample - loss: 0.1305 - binary_accuracy: 0.9366
# Epoch 81/100
# 426/426 [==============================] - 0s 171us/sample - loss: 0.1404 - binary_accuracy: 0.9460
# Epoch 82/100
# 426/426 [==============================] - 0s 131us/sample - loss: 0.1658 - binary_accuracy: 0.9460
# Epoch 83/100
# 426/426 [==============================] - 0s 131us/sample - loss: 0.1153 - binary_accuracy: 0.9507
# Epoch 84/100
# 426/426 [==============================] - 0s 140us/sample - loss: 0.1403 - binary_accuracy: 0.9272
# Epoch 85/100
# 426/426 [==============================] - 0s 136us/sample - loss: 0.1140 - binary_accuracy: 0.9531
# Epoch 86/100
# 426/426 [==============================] - 0s 126us/sample - loss: 0.1162 - binary_accuracy: 0.9507
# Epoch 87/100
# 426/426 [==============================] - 0s 119us/sample - loss: 0.1138 - binary_accuracy: 0.9577
# Epoch 88/100
# 426/426 [==============================] - 0s 143us/sample - loss: 0.1224 - binary_accuracy: 0.9554
# Epoch 89/100
# 426/426 [==============================] - 0s 194us/sample - loss: 0.1244 - binary_accuracy: 0.9507
# Epoch 90/100
# 426/426 [==============================] - 0s 138us/sample - loss: 0.0999 - binary_accuracy: 0.9648
# Epoch 91/100
# 426/426 [==============================] - 0s 157us/sample - loss: 0.1131 - binary_accuracy: 0.9484
# Epoch 92/100
# 426/426 [==============================] - 0s 140us/sample - loss: 0.1139 - binary_accuracy: 0.9413
# Epoch 93/100
# 426/426 [==============================] - 0s 147us/sample - loss: 0.1078 - binary_accuracy: 0.9601
# Epoch 94/100
# 426/426 [==============================] - 0s 155us/sample - loss: 0.1054 - binary_accuracy: 0.9531
# Epoch 95/100
# 426/426 [==============================] - 0s 151us/sample - loss: 0.1086 - binary_accuracy: 0.9554
# Epoch 96/100
# 426/426 [==============================] - 0s 140us/sample - loss: 0.1173 - binary_accuracy: 0.9484
# Epoch 97/100
# 426/426 [==============================] - 0s 157us/sample - loss: 0.1058 - binary_accuracy: 0.9531
# Epoch 98/100
# 426/426 [==============================] - 0s 147us/sample - loss: 0.1214 - binary_accuracy: 0.9507
# Epoch 99/100
# 426/426 [==============================] - 0s 145us/sample - loss: 0.1048 - binary_accuracy: 0.9554
# Epoch 100/100
# 426/426 [==============================] - 0s 155us/sample - loss: 0.0913 - binary_accuracy: 0.9577

# %%
# Prevendo com o modelo
pred = model.predict(X_test)
pred = (pred > 0.5)

# Avaliação
acc =  accuracy_score(y_test, pred)
matriz = confusion_matrix(y_test, pred)

# %%
# Accuracy do modelo
acc
# Out:
# 0.8671328671328671

# %%
# Acertos por erros
pd.DataFrame(matriz)
# Out:
#     0   1
# 0  38  13
# 1   6  86
